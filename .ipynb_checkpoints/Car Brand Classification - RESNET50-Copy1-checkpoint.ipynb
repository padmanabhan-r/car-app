# %% [markdown]
# ### Importing all genaral libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob

# %matplotlib inline

# %% [markdown]
# ### Importing all TF libraries

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Lambda, Flatten
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %%
# import tensorflow as tf
# #print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# tf.config.experimental.list_physical_devices('GPU')
# tf.debugging.set_log_device_placement(True)

# %% [markdown]
# ### Resnet

# %%
IMAGE_SIZE = [224, 224]
resnet = ResNet50(
    include_top=False,
    weights='imagenet',
    input_shape=IMAGE_SIZE + [3] ## RGB Channels
)

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %% [markdown]
# ### Inital Steps

# %%
train_path = 'Datasets/Train/'
valid_path = 'Datasets/Test/'

# %%
folders = glob('Datasets/Train/*') # To get the number of classes/folders

# %%
folders
# Out:
# ['Datasets/Train\\audi',
#  'Datasets/Train\\lamborghini',
#  'Datasets/Train\\mercedes']

# %%
num_class = len(folders)

# %%
num_class
# Out:
# 3

# %%
for layer in resnet.layers:
    layer.trainable = False #We dont want to retrain the weights

# %% [markdown]
# ### Before going into the dense layers, the op needs to be flattened

# %%
resnet.output
# Out:
# <KerasTensor: shape=(None, 7, 7, 2048) dtype=float32 (created by layer 'conv5_block3_out')>

# %%
x = Flatten()(resnet.output)

# %%
x #flattened
# Out:
# <KerasTensor: shape=(None, 100352) dtype=float32 (created by layer 'flatten')>

# %%
###

# %%
prediction = Dense(num_class, activation='softmax')(x)

# %%
prediction
# Out:
# <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'dense')>

# %%
model = Model(inputs = resnet.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
resnet.input
# Out:
# <KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_1')>

# %%
prediction
# Out:
# <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'dense')>

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
##Data preprocessing

# %%
train_datagen = ImageDataGenerator(rescale=1./255, 
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True
                                  )
test_datagen = train_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(directory=train_path, 
                                                target_size=(224,224),
                                                batch_size=32,
                                                class_mode='categorical'
                                                )
# Out:
# Found 65 images belonging to 3 classes.

# %%
test_set = test_datagen.flow_from_directory(directory=valid_path, 
                                                target_size=(224,224),
                                                batch_size=32,
                                                class_mode='categorical'
                                                )
# Out:
# Found 58 images belonging to 3 classes.

# %%
#fit the model

# %%
r = model.fit(training_set,
                       validation_data=test_set,
                       epochs=50,
                       steps_per_epoch = len(training_set),
                       validation_steps=len(test_set)
                       )
# Out:
# Epoch 1/50
# 3/3 [==============================] - 7s 2s/step - loss: 4.2841 - accuracy: 0.3215 - val_loss: 5.4624 - val_accuracy: 0.3448
# Epoch 2/50
# 3/3 [==============================] - 1s 273ms/step - loss: 2.5138 - accuracy: 0.6008 - val_loss: 5.1661 - val_accuracy: 0.5172
# Epoch 3/50
# 3/3 [==============================] - 1s 275ms/step - loss: 5.4144 - accuracy: 0.3217 - val_loss: 5.4619 - val_accuracy: 0.1552
# Epoch 4/50
# 3/3 [==============================] - 1s 276ms/step - loss: 2.9700 - accuracy: 0.4764 - val_loss: 5.4901 - val_accuracy: 0.3276
# Epoch 5/50
# 3/3 [==============================] - 1s 277ms/step - loss: 6.0689 - accuracy: 0.3462 - val_loss: 2.7735 - val_accuracy: 0.6034
# Epoch 6/50
# 3/3 [==============================] - 1s 278ms/step - loss: 2.6526 - accuracy: 0.6078 - val_loss: 3.4018 - val_accuracy: 0.2759
# Epoch 7/50
# ...

# %%
loss_df = pd.DataFrame(r.history)

# %%
loss_df[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
model.save('model_resnet50.h5')

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2462-F200
#
#  Directory of C:\Users\Paddy\Documents\GitHub\car brand
#
# 01/02/2021  06:58 PM    <DIR>          .
# 01/02/2021  06:58 PM    <DIR>          ..
# 01/02/2021  02:39 PM    <DIR>          .ipynb_checkpoints
# 01/02/2021  06:58 PM            98,504 Car Brand Classification - RESNET50.ipynb
# 01/02/2021  02:33 PM    <DIR>          Datasets
# 01/02/2021  04:36 PM    <DIR>          downloads
# 01/02/2021  06:59 PM        98,477,256 model_resnet50.h5
#                2 File(s)     98,575,760 bytes
#                5 Dir(s)  183,758,524,416 bytes free

# %% [markdown]
# ### The model has been saved

# %%
y_pred = model.predict(test_set)

# %%
y_pred
# Out:
# array([[1.70091242e-02, 3.85151654e-02, 9.44475651e-01],
#        [1.32398773e-02, 2.11824775e-01, 7.74935305e-01],
#        [2.69012526e-02, 9.46637869e-01, 2.64608096e-02],
#        [3.71331139e-03, 9.91914868e-01, 4.37191734e-03],
#        [1.21012973e-02, 4.08274323e-01, 5.79624355e-01],
#        [1.86914741e-03, 9.95948374e-01, 2.18249392e-03],
#        [9.97706413e-01, 1.43211859e-03, 8.61419539e-04],
#        [3.30062211e-01, 2.45249107e-01, 4.24688727e-01],
#        [4.58089203e-01, 2.80671537e-01, 2.61239231e-01],
#        [9.25001949e-02, 3.42158824e-01, 5.65340996e-01],
#        [4.53590095e-04, 9.98502851e-01, 1.04356022e-03],
#        [2.39220541e-02, 3.57578695e-01, 6.18499279e-01],
#        [7.19788542e-04, 9.63357210e-01, 3.59229743e-02],
#        [9.11892205e-02, 1.74695216e-02, 8.91341269e-01],
#        [2.21386701e-01, 3.61694545e-01, 4.16918725e-01],
#        [7.58508801e-01, 6.08962812e-02, 1.80594951e-01],
# ...

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('model_resnet50.h5')

# %%
img = image.load_img('Datasets/Test/lamborghini/10.jpg', target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1B27CA64670>

# %%
x = image.img_to_array(img)

# %%
x
# Out:
# array([[[ 17.,   7.,   0.],
#         [ 17.,   7.,   0.],
#         [ 17.,   7.,   0.],
#         ...,
#         [ 13.,   2.,   0.],
#         [ 14.,   4.,   3.],
#         [ 14.,   4.,   3.]],
#
#        [[ 17.,   7.,   0.],
#         [ 17.,   7.,   0.],
#         [ 18.,   8.,   0.],
#         ...,
#         [ 14.,   3.,   1.],
#         [ 14.,   4.,   3.],
#         [ 14.,   4.,   3.]],
#
#        [[ 18.,   8.,   0.],
#         [ 18.,   8.,   0.],
#         [ 19.,   9.,   0.],
#         ...,
#         [ 14.,   3.,   1.],
#         [ 14.,   4.,   3.],
#         [ 14.,   4.,   3.]],
#
#        ...,
#
#        [[209., 129.,  92.],
#         [210., 130.,  93.],
#         [212., 132.,  95.],
#         ...,
#         [216., 132.,  96.],
#         [214., 129.,  92.],
#         [213., 129.,  92.]],
#
#        [[208., 128.,  91.],
#         [208., 128.,  91.],
#         [211., 131.,  94.],
#         ...,
#         [215., 131.,  95.],
#         [209., 129.,  94.],
# ...

# %%
x = x/255

# %%
x
# Out:
# array([[[0.06666667, 0.02745098, 0.        ],
#         [0.06666667, 0.02745098, 0.        ],
#         [0.06666667, 0.02745098, 0.        ],
#         ...,
#         [0.05098039, 0.00784314, 0.        ],
#         [0.05490196, 0.01568628, 0.01176471],
#         [0.05490196, 0.01568628, 0.01176471]],
#
#        [[0.06666667, 0.02745098, 0.        ],
#         [0.06666667, 0.02745098, 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.05490196, 0.01176471, 0.00392157],
#         [0.05490196, 0.01568628, 0.01176471],
#         [0.05490196, 0.01568628, 0.01176471]],
#
#        [[0.07058824, 0.03137255, 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         [0.07450981, 0.03529412, 0.        ],
#         ...,
#         [0.05490196, 0.01176471, 0.00392157],
#         [0.05490196, 0.01568628, 0.01176471],
#         [0.05490196, 0.01568628, 0.01176471]],
#
#        ...,
#
#        [[0.81960785, 0.5058824 , 0.36078432],
# ...

# %%
x = np.expand_dims(x, axis=0)

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
img_data = preprocess_input(x)

# %%
img_data.shape
# Out:
# (1, 224, 224, 3)

# %%
img_pred = model.predict(img_data)

# %%
a = np.argmax(img_pred, axis=1)

# %%
a == 1
# Out:
# array([ True])
